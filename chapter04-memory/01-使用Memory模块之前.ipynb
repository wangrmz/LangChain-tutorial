# %%
# 1、获取大模型
import os
import dotenv
from langchain_core.messages import AIMessage
from langchain_openai import ChatOpenAI

dotenv.load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY1")
os.environ['OPENAI_BASE_URL'] = os.getenv("OPENAI_BASE_URL")

# 创建大模型实例
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages.ai import AIMessage


def chat_with_model(answer):
    # 2、提供提示词模板：ChatPromptTemplate
    prompt_template = ChatPromptTemplate.from_messages([
        ("system", "你是一个人工智能的助手"),
        ("human", "{question}")
    ])

    while True:
        # 3、获取chain，并调用大模型得到响应
        chain = prompt_template | llm
        response = chain.invoke({"question": answer})

        # 4、输出大模型的响应
        print(f"模型回复：{response.content}")

        # 5、继续获取用户的问题
        user_input = input("你还有其他问题吗？(输入'退出'时，结束会话)")

        # 6、指明退出循环的方式
        if (user_input == "退出"):
            break

        # 7、将上述新生成的消息存放到提示词模板的消息列表中
        # 使用append方法添加： LLM的反馈，用户输入
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))


chat_with_model("你好，很高兴认识你！")
# Out:
# 模型回复：你好！很高兴认识你！有什么我可以帮助你的吗？
# 模型回复：苏轼是中国北宋时期著名的文学家、书法家和政治家，他的诗词涵盖了多种主题，风格多样。以下是一些他比较出名的诗词及其简单介绍：
#
# 1. **《念奴娇·赤壁怀古》**
#    - 这首词是苏轼最著名的作品之一，抒发了他对历史的感慨，回忆起古战场赤壁的壮丽和英雄豪情。词中描绘了壮丽的自然景色，并表达了对历史人物的敬仰与对人生短暂的感悟。
#
# 2. **《水调歌头·明月几时有》**
#    - 这首词以明月为主题，表达了苏轼对亲人的思念和人生哲理的思考。他抒发了对家乡的深切怀念，也探讨了人生的无常和对美好时光的向往。可以说是表达情感与哲理的经典之作。
#
# 3. **《定风波·莫听穿腔子》**
#    - 此词以平和的语气，借景抒情，展现了苏轼的豁达与洒脱。他反思人生中的遭遇和艰难，强调乐观面对生活的态度，非常具有感染力。
#
# 4. **《题西林壁》**
#    - 这是一首描绘自然景色的诗，以及探讨事物的不同角度的诗。诗中通过“横看成岭侧成峰”的描写，表达了看事物要有多元的视角，极富哲理性。
#
# 5. **《江城子·乙卯正月二十日夜记梦》**
#    - 这首词展现了苏轼对爱人的思念，通过梦境表达了他复杂而深刻的情感，情感细腻且富有张力。
#
# 苏轼的诗词不仅在艺术上达到了很高的成就，也反映了他的人生智慧，值得细细品味。如果你对某一首诗或某一主题感兴趣，可以告诉我，我可以提供更多的解读或信息！
