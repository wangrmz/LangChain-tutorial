# %%
# LangChain调用本地大模型

# %% [markdown]
# 1、下载并安装Ollama
# 2、在Ollama下部署大模型 deepseek-r1:7b
# 3、在LangChain中调用Ollama下的大模型
#
# 安装或者调用本地大模型  ollama run deepseek-r1:7b

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.messages import HumanMessage
#from langchain_ollama import ChatOllama

# 此时调用的是本地大模型 。省略base_url 、api-key
ollama_llm = ChatOllama(model="deepseek-r1:7b")


messages = [
    HumanMessage(content="你好，请介绍一下你自己")
]
chat_model_response = ollama_llm.invoke(messages)
print(chat_model_response.content)
# Out:
# /var/folders/9z/fc7qnwdj7rn5p5zkh6ckfq740000gn/T/ipykernel_22938/3872411184.py:6: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   ollama_llm = ChatOllama(model="deepseek-r1:7b")
# 您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。如您有任何任何问题，我会尽我所能为您提供帮助。
