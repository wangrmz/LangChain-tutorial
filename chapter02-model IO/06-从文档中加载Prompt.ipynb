# %% [markdown]
# 从文档中加载Prompt

# %% [markdown]
# 举例1:从物理磁盘的yaml文件中读取prompt数据

# %%
from langchain_core.prompts import load_prompt
from dotenv import load_dotenv

load_dotenv()
prompt = load_prompt("prompt.yaml", encoding="utf-8")
# print(prompt)
print(prompt.format(name="年轻人", what="滑稽"))  # 请给年轻人讲一个关于滑稽的故事
# Out:
# 请给年轻人讲一个关于滑稽的故事

# %% [markdown]
# 举例2:从物理磁盘的json文件中读取prompt数据

# %%
from langchain_core.prompts import load_prompt
from dotenv import load_dotenv

load_dotenv()
prompt = load_prompt("prompt.json", encoding="utf-8")
print(prompt.format(name="张三", what="搞笑的")) # 请张三讲一个搞笑的的故事。
# Out:
# 请张三讲一个搞笑的的故事。
